# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from model import Market
import seaborn as sns
from agents import Firm
from model import Market

import networkx as nx

# %%
n_households = 50
n_firms = 5
firms_production = 12
min_income = 0
max_income = 10
min_quality = 0
max_quality = 1
decrease_price = 0.7
increase_price = 0.3
price_change = 0.01
toy_mode = False

model = Market(F =n_firms, H=n_households, firms_production=firms_production, min_income=min_income, max_income=max_income, 
                min_quality=min_quality, max_quality=max_quality, decrease_price=decrease_price, increase_price=increase_price, price_change=price_change, toy_mode=toy_mode)
steps = 10
for i in range(steps):
    #print('step', i)
    model.step()

# %%
a = model.datacollector.get_agent_vars_dataframe()
a
# Out:
#                    Type   Quality   Revenue  Quantity_sold     Price  \
# Step AgentID
# 0    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  0.000000            0.0  1.000000
#      4             Firm  0.164826  0.000000            0.0  1.000000
# 1    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.000000            1.0  1.010000
#      4             Firm  0.164826  1.000000            1.0  1.010000
# 2    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.010000            1.0  1.020100
#      4             Firm  0.164826  1.010000            1.0  1.020100
# 3    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.020100            1.0  1.030301
#      4             Firm  0.164826  1.020100            1.0  1.030301
# 4    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.030301            1.0  1.040604
#      4             Firm  0.164826  1.030301            1.0  1.040604
# 5    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.040604            1.0  1.051010
#      4             Firm  0.164826  1.040604            1.0  1.051010
# 6    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.051010            1.0  1.061520
#      4             Firm  0.164826  1.051010            1.0  1.061520
# 7    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.061520            1.0  1.072135
#      4             Firm  0.164826  1.061520            1.0  1.072135
# 8    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.072135            1.0  1.082857
#      4             Firm  0.164826  1.072135            1.0  1.082857
# 9    1        Household       NaN       NaN            NaN       NaN
#      2        Household       NaN       NaN            NaN       NaN
#      3             Firm  0.700463  1.082857            1.0  1.093685
#      4             Firm  0.164826  1.082857            1.0  1.093685
#
#               Initial_budget    budget
# Step AgentID
# 0    1              7.014345  7.014345
#      2              0.122169  0.122169
#      3                   NaN       NaN
#      4                   NaN       NaN
# 1    1              7.014345  6.014345
#      2              0.122169 -0.877831
#      3                   NaN       NaN
#      4                   NaN       NaN
# 2    1              7.014345  5.004345
#      2              0.122169 -1.887831
#      3                   NaN       NaN
#      4                   NaN       NaN
# 3    1              7.014345  3.984245
#      2              0.122169 -2.907931
#      3                   NaN       NaN
#      4                   NaN       NaN
# 4    1              7.014345  2.953944
#      2              0.122169 -3.938232
#      3                   NaN       NaN
#      4                   NaN       NaN
# 5    1              7.014345  1.913340
#      2              0.122169 -4.978836
#      3                   NaN       NaN
#      4                   NaN       NaN
# 6    1              7.014345  0.862330
#      2              0.122169 -6.029846
#      3                   NaN       NaN
#      4                   NaN       NaN
# 7    1              7.014345 -0.199190
#      2              0.122169 -7.091366
#      3                   NaN       NaN
#      4                   NaN       NaN
# 8    1              7.014345 -1.271326
#      2              0.122169 -8.163502
#      3                   NaN       NaN
#      4                   NaN       NaN
# 9    1              7.014345 -2.354182
#      2              0.122169 -9.246358
#      3                   NaN       NaN
#      4                   NaN       NaN

# %%
# draw the graph of the last step with  Weight
# remove the nodes with no edges
for i in range(len(model.graphs)):
    if i % 1 == 0:
        # model.graphs[i].remove_nodes_from(list(nx.isolates(model.graphs[i])))
        # color the nodes by type
        color_map = []
        node_map = []
        pos = {}
        f = 1
        h = 1
        for node in model.graphs[i]:
            if type(node) is Firm:
                color_map.append('blue')
                node_map.append(50)
                pos[node] = (1, f * 10)
                f += 1
            else:
                color_map.append('red')
                node_map.append(2)
                pos[node] = (2, h)
                h += 1
        fig, ax = plt.subplots(1, 1, figsize=(10, 10))
        # draw the bipartite graph using the node color map

        nx.draw(model.graphs[i], with_labels=False, width=[model.graphs[i][u][v]['weight'] for u,v in model.graphs[i].edges()], node_color = color_map, node_size = node_map, pos=pos)
        #plt.show()

# %%
df = model.datacollector.get_agent_vars_dataframe().reset_index()

# %%
# for each Step, computes the HHI for each Firm
df_firm = df.loc[df['Type'] == 'Firm']
# normalize df_firm['Revenue'] in each Step
df_firm['Market_share'] = df_firm.groupby(['Step'])['Revenue'].transform(lambda x: x/x.sum())
# square the Market_share
df_firm['R'] = df_firm['Market_share']**2
# compute the HHI
HHI = df_firm.groupby(['Step'])['R'].sum()

#df_firm['HHI'] = df_firm.groupby(['Step'])['Revenue'].transform(lambda x: x**2).groupby(['Step', 'Type']).transform('sum')
# Out:
# /var/folders/cy/01tnmvcx0_d54pv4f2k6dkv40000gn/T/ipykernel_74454/3487603048.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_firm['Market_share'] = df_firm.groupby(['Step'])['Revenue'].transform(lambda x: x/x.sum())
# /var/folders/cy/01tnmvcx0_d54pv4f2k6dkv40000gn/T/ipykernel_74454/3487603048.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_firm['R'] = df_firm['Market_share']**2

# %%
def change_metric(graphs):
    """
    Takes in a list of transaction graphs and returns a list of the change between each
    """
    output = [0]
    for i in range(0, len(graphs)):
        prev = nx.adjacency_matrix(graphs[i-1]).A
        curr = nx.adjacency_matrix(graphs[i]).A
        change = sum(sum(abs(curr - prev)))
        maximum = sum(sum(prev)) + sum(sum(curr))
        output.append(change/maximum)
    return output

our_metric = change_metric(model.graphs)
plt.plot(our_metric)
# Out:
# /Users/todd/WWCS_2023_markets/env/lib/python3.9/site-packages/scipy/sparse/_base.py:752: VisibleDeprecationWarning: Please use `.todense()` instead
#   warn(np.VisibleDeprecationWarning(

# %%
HHI.plot()
# Out:
# <AxesSubplot: xlabel='Step'>

# %%
def compute_hhi_diff(hhi):
    hhi_diff = [0]

    for i in range(1, len(hhi)):
        change = abs(hhi[i] - hhi[i-1])
        hhi_diff.append(change)

    return hhi_diff

plt.plot(our_metric)
plt.plot(compute_hhi_diff(HHI))

# %%
#sns.lineplot(data=df, y='Revenue', x='Step', estimator='sum')
sns.lineplot(data=df, y='budget', x='Step', estimator='sum')
sns.lineplot(data=df, y='Initial_budget', x='Step', estimator='sum')
sns.lineplot(data=df, y='Revenue', x='Step', estimator='sum')
# Out:
# <AxesSubplot: xlabel='Step', ylabel='budget'>

# %%
sns.lineplot(data=df_firm, y='Price', x='Step', hue = 'AgentID')
# Out:
# <AxesSubplot: xlabel='Step', ylabel='Price'>

# %%
sns.lineplot(data=df, y='Quantity_sold', x='Step', estimator='sum')
# Out:
# <AxesSubplot: xlabel='Step', ylabel='Quantity_sold'>

# %%
sns.lineplot(data=df, y='Revenue', x='Step')
# Out:
# <AxesSubplot: xlabel='Step', ylabel='Revenue'>

# %%
sns.lineplot(data=df.loc[df['AgentID'] == 1020],
             y='Revenue', x='Step', hue='AgentID')
# Out:
# <AxesSubplot: >

# %%
df.loc[(df['Step'] == 0) & (df['Type'] == 'Household')].sort_values('budget')
# Out:
#    Step  AgentID       Type  Quality  Revenue  Quantity_sold  Price  \
# 1     0        2  Household      NaN      NaN            NaN    NaN
# 0     0        1  Household      NaN      NaN            NaN    NaN
#
#    Initial_budget    budget
# 1        0.122169  0.122169
# 0        7.014345  7.014345

# %%
df.loc[(df['Step'] == 0) & (df['Type'] == 'Firm')].sort_values('Quality')
# Out:
#    Step  AgentID  Type   Quality  Revenue  Quantity_sold  Price  \
# 3     0        4  Firm  0.164826      0.0            0.0    1.0
# 2     0        3  Firm  0.700463      0.0            0.0    1.0
#
#    Initial_budget  budget
# 3             NaN     NaN
# 2             NaN     NaN

# %%
sns.barplot(data=df.loc[(df['Step'] == 0) & (
    df['Type'] == 'Firm')], y='Quality', x='AgentID')
# Out:
# <AxesSubplot: xlabel='AgentID', ylabel='Quality'>

# %%
df.loc[df['AgentID'] == 1009]
# Out:
# Empty DataFrame
# Columns: [Step, AgentID, Type, Quality, Revenue, Quantity_sold, Price, Initial_budget, budget]
# Index: []

# %%
# for each step plot use seaborn to do a 1x2 plot with the distribution of the "Price" and "Revenue" of the firms
for i in range(steps):
    if i % 10 == 0:
        df1 = df[df["Step"] == i]
        df1 = df1[df1["Type"] == "Firm"]
        fig, ax = plt.subplots(1, 2, figsize=(12, 5))

        sns.histplot(df1["Price"], ax=ax[0])
        sns.histplot(df1["Revenue"], ax=ax[1])
        # set the title of the plot to the step
        fig.suptitle("Step " + str(i))
        plt.show()

# %%
firms = df.loc[df['Type'] == "Firm"]
df.loc[(df['Type'] == "Firm") & (df['Step'] == 99)]['Revenue'].sum()
hhi = pd.DataFrame(data={'step': range(0,100)})
hhi = hhi.assign(volume=lambda x: df.loc[(df['Type'] == "Firm") & (df['Step'] == x.step)]['Revenue'].sum())
hhi
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 df.loc[(df['Type'] == "Firm") & (df['Step'] == 99)]['Revenue'].sum()
#       3 hhi = pd.DataFrame(data={'step': range(0,100)})
# ----> 4 hhi = hhi.assign(volume=lambda x: df.loc[(df['Type'] == "Firm") & (df['Step'] == x.step)]['Revenue'].sum())
#       5 hhi
#
# File ~/WWCS_2023_markets/env/lib/python3.9/site-packages/pandas/core/frame.py:4889, in DataFrame.assign(self, **kwargs)
#    4886 data = self.copy()
#    4888 for k, v in kwargs.items():
# -> 4889     data[k] = com.apply_if_callable(v, data)
#    4890 return data
#
# File ~/WWCS_2023_markets/env/lib/python3.9/site-packages/pandas/core/common.py:374, in apply_if_callable(maybe_callable, obj, **kwargs)
#     363 """
#     364 Evaluate possibly callable input using obj and kwargs if it is callable,
#     365 otherwise return as it is.
#    (...)
#     371 **kwargs
#     372 """
#     373 if callable(maybe_callable):
# --> 374     return maybe_callable(obj, **kwargs)
#     376 return maybe_callable
#
# Cell In[20], line 4, in <lambda>(x)
#       2 df.loc[(df['Type'] == "Firm") & (df['Step'] == 99)]['Revenue'].sum()
#       3 hhi = pd.DataFrame(data={'step': range(0,100)})
# ----> 4 hhi = hhi.assign(volume=lambda x: df.loc[(df['Type'] == "Firm") & (df['Step'] == x.step)]['Revenue'].sum())
#       5 hhi
#
# File ~/WWCS_2023_markets/env/lib/python3.9/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/WWCS_2023_markets/env/lib/python3.9/site-packages/pandas/core/arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~/WWCS_2023_markets/env/lib/python3.9/site-packages/pandas/core/series.py:6237, in Series._cmp_method(self, other, op)
#    6234 res_name = ops.get_op_result_name(self, other)
#    6236 if isinstance(other, Series) and not self._indexed_same(other):
# -> 6237     raise ValueError("Can only compare identically-labeled Series objects")
#    6239 lvalues = self._values
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects
